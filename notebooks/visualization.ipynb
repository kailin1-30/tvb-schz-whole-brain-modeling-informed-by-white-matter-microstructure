# %%
import os
import sys

sys.path.append(os.path.join(os.getcwd(), "..", "src"))

import numpy as np
from tools import visualize_BOLD

PATH_result = os.path.join(os.getcwd(), "..", "outputs")

# %%
# visualization of the BOLD signal

data = np.load(f"{PATH_result}/BOLD_signal.npy", allow_pickle=True).item()
visualize_BOLD(data)
