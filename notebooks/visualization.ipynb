# %%
# visualization of the BOLD signal

data = np.load(PATH_result + 'BOLD_signal.npy', allow_pickle=True).item()
visualize_BOLD(data)
# Out:
# The kernel died. Error: /Users/lin/Documents/Bachelor thesis /.venv/bin/python: No module named ipykernel_launcher... View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
